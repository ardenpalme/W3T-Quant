# %%
from vectorbtpro import *
from dune_client.client import DuneClient
import fedfred as fd

import tzlocal
import pytz

# %% [markdown]
# # Data Fetching

# %% [markdown]
# In this notebook we fetch the data necessary for the ML strategies, and technical analysis (TA) strategies. We use third-party data providers, with which you will have to sign up and register keys (for free).
#
# * [Dune Analytics](https://docs.dune.com/api-reference/overview/authentication)
# * [Federal Reserve Bank of St. Louis (FRED)](https://fred.stlouisfed.org/docs/api/api_key.html)
#
# Then create a file in the current directory named `.env` with the following:
# ```
# DUNE_API_KEY=<key>
# FRED_API_KEY=<key>
# ```

# %%
tzlocal.get_localzone = lambda: pytz.timezone('UTC')

# %%
# retrieve API keys from environment
api_keys = dict()
with open(".env") as f:
    for line in f.readlines():
        elems = line.split("=")
        api_keys[elems[0].strip()] = elems[1].strip()
api_keys
# Out:
# {'DUNE_API_KEY': 'hafQP5vPw8oF8qovHAiwbLTbxpdN95gW',
#  'FRED_API_KEY': '3a535693a7c1bb047269acdb2e4d7a0a'}

# %%
dune = DuneClient(api_key=api_keys['DUNE_API_KEY'])
fred = fd.FredAPI(api_key=api_keys['FRED_API_KEY'])

# %%
START_DATE = "2024-04-01"
END_DATE = "2025-12-18"
res_df = pd.DataFrame(index=pd.date_range(START_DATE, END_DATE, tz='UTC'))

# %% [markdown]
# The goal is to add useful features to our model: variables that could impact price performance of SOLUSD. For example the [M2 money supply](https://fred.stlouisfed.org/series/M2SL) macro-economic indicator could be a way to track QE which impacts BTC and SOL.

# %%
for tix in ["SPY", "NDX", "^VIX", "QQQ", "BTC-USD", "SOL-USD"]:
    data = vbt.YFData.pull(
        tix,
        start=START_DATE,
        end=END_DATE,
        timeframe="1 day",
        tz="UTC"
    )
    df = data.get()
    df.index = pd.to_datetime(df.index, utc=True).normalize()
    res_df = res_df.join(df, lsuffix=f"_{tix}")

# %%
for tix in ['DGS10','GDP','FEDFUNDS','WALCL','M2V','M2SL', 'DTWEXBGS']:
    b10 = fred.get_series_observations(tix)
    ser = b10['value'][START_DATE:]
    ser.index = pd.to_datetime(ser.index, utc=True).normalize()
    res_df[tix] = ser
    
res_df = res_df.ffill() # forward-fill infrequently-observed timeseries

# %%
query_result = dune.get_latest_result(3930956)
metrics_df = pd.DataFrame(query_result.result.rows)
metrics_df.set_index('time_period', inplace=True)
metrics_df.index = pd.to_datetime(metrics_df.index, utc=True).normalize()
res_df = res_df.join(metrics_df)

# %%
res_df.columns
# Out:
# Index(['Open_NDX', 'High_NDX', 'Low_NDX', 'Close_NDX', 'Volume_NDX',
#        'Dividends_NDX', 'Stock Splits_NDX', 'Capital Gains_QQQ', 'Open_^VIX',
#        'High_^VIX', 'Low_^VIX', 'Close_^VIX', 'Volume_^VIX', 'Dividends_^VIX',
#        'Stock Splits_^VIX', 'Open_QQQ', 'High_QQQ', 'Low_QQQ', 'Close_QQQ',
#        'Volume_QQQ', 'Dividends_QQQ', 'Stock Splits_QQQ', 'Open_BTC-USD',
#        'High_BTC-USD', 'Low_BTC-USD', 'Close_BTC-USD', 'Volume_BTC-USD',
#        'Dividends_BTC-USD', 'Stock Splits_BTC-USD', 'Capital Gains',
#        'Open_SOL-USD', 'High_SOL-USD', 'Low_SOL-USD', 'Close_SOL-USD',
#        'Volume_SOL-USD', 'Dividends_SOL-USD', 'Stock Splits_SOL-USD', 'Open',
#        'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits', 'DGS10',
#        'GDP', 'FEDFUNDS', 'WALCL', 'M2V', 'M2SL', 'DTWEXBGS',
#        'market_capitalization', 'mvrv', 'nupl', 'price',
#        'realized_capitalization', 'realized_price', 'supply'],
#       dtype='object')

# %%
res_df
# Out:
#                              Open_NDX    High_NDX     Low_NDX   Close_NDX  \
# 2024-04-01 00:00:00+00:00  512.781120  513.319507  509.981399  511.146301
# 2024-04-02 00:00:00+00:00  507.308921  508.033303  505.586035  507.896301
# 2024-04-03 00:00:00+00:00  506.799898  509.961810  506.750965  508.454254
# 2024-04-04 00:00:00+00:00  512.477579  512.820173  501.944527  502.247986
# 2024-04-05 00:00:00+00:00  503.608761  509.462609  503.168241  507.494995
# ...                               ...         ...         ...         ...
# 2025-12-14 00:00:00+00:00  686.142492  686.850422  677.169008  679.751404
# 2025-12-15 00:00:00+00:00  683.719676  683.739636  677.248806  678.724426
# 2025-12-16 00:00:00+00:00  677.228859  679.073445  672.991380  676.869934
# 2025-12-17 00:00:00+00:00  677.886913  678.435280  669.222513  669.421936
# 2025-12-18 00:00:00+00:00  677.886913  678.435280  669.222513  669.421936
#
#                             Volume_NDX  Dividends_NDX  Stock Splits_NDX  \
# 2024-04-01 00:00:00+00:00   62477500.0            0.0               0.0
# 2024-04-02 00:00:00+00:00   74230300.0            0.0               0.0
# 2024-04-03 00:00:00+00:00   59155800.0            0.0               0.0
# 2024-04-04 00:00:00+00:00   96858100.0            0.0               0.0
# 2024-04-05 00:00:00+00:00   74546500.0            0.0               0.0
# ...                                ...            ...               ...
# 2025-12-14 00:00:00+00:00  113160300.0            0.0               0.0
# 2025-12-15 00:00:00+00:00   90811000.0            0.0               0.0
# 2025-12-16 00:00:00+00:00  122030600.0            0.0               0.0
# 2025-12-17 00:00:00+00:00  110625200.0            0.0               0.0
# 2025-12-18 00:00:00+00:00  110625200.0            0.0               0.0
#
#                            Capital Gains_QQQ     Open_^VIX     High_^VIX  ...  \
# 2024-04-01 00:00:00+00:00                0.0  18293.199219  18293.199219  ...
# 2024-04-02 00:00:00+00:00                0.0  18121.779297  18121.779297  ...
# 2024-04-03 00:00:00+00:00                0.0  18160.189453  18160.189453  ...
# 2024-04-04 00:00:00+00:00                0.0  17878.779297  17878.779297  ...
# 2024-04-05 00:00:00+00:00                0.0  18108.460938  18108.460938  ...
# ...                                      ...           ...           ...  ...
# 2025-12-14 00:00:00+00:00                0.0  25196.730469  25196.730469  ...
# 2025-12-15 00:00:00+00:00                0.0  25067.259766  25067.259766  ...
# 2025-12-16 00:00:00+00:00                0.0  25132.939453  25132.939453  ...
# 2025-12-17 00:00:00+00:00                0.0  24647.609375  24647.609375  ...
# 2025-12-18 00:00:00+00:00                0.0  24647.609375  24647.609375  ...
#
#                              M2V     M2SL  DTWEXBGS  market_capitalization  \
# 2024-04-01 00:00:00+00:00  1.389  20929.1  121.5151                    NaN
# 2024-04-02 00:00:00+00:00  1.389  20929.1  121.3035                    NaN
# 2024-04-03 00:00:00+00:00  1.389  20929.1  121.0198                    NaN
# 2024-04-04 00:00:00+00:00  1.389  20929.1  120.7613                    NaN
# 2024-04-05 00:00:00+00:00  1.389  20929.1  120.9646                    NaN
# ...                          ...      ...       ...                    ...
# 2025-12-14 00:00:00+00:00  1.406  22411.0  120.1442           3.907911e+08
# 2025-12-15 00:00:00+00:00  1.406  22411.0  119.9561           3.835396e+08
# 2025-12-16 00:00:00+00:00  1.406  22411.0  119.8902           3.710720e+08
# 2025-12-17 00:00:00+00:00  1.406  22411.0  120.1550           3.716993e+08
# 2025-12-18 00:00:00+00:00  1.406  22411.0  120.0528           3.501397e+08
#
#                                mvrv      nupl     price  \
# 2024-04-01 00:00:00+00:00       NaN       NaN       NaN
# 2024-04-02 00:00:00+00:00       NaN       NaN       NaN
# 2024-04-03 00:00:00+00:00       NaN       NaN       NaN
# 2024-04-04 00:00:00+00:00       NaN       NaN       NaN
# 2024-04-05 00:00:00+00:00       NaN       NaN       NaN
# ...                             ...       ...       ...
# 2025-12-14 00:00:00+00:00  0.510863 -0.957474  0.391186
# 2025-12-15 00:00:00+00:00  0.505826 -0.976964  0.383927
# 2025-12-16 00:00:00+00:00  0.491650 -1.033967  0.371447
# 2025-12-17 00:00:00+00:00  0.490334 -1.039425  0.372075
# 2025-12-18 00:00:00+00:00  0.467714 -1.138060  0.350493
#
#                            realized_capitalization  realized_price  \
# 2024-04-01 00:00:00+00:00                      NaN             NaN
# 2024-04-02 00:00:00+00:00                      NaN             NaN
# 2024-04-03 00:00:00+00:00                      NaN             NaN
# 2024-04-04 00:00:00+00:00                      NaN             NaN
# 2024-04-05 00:00:00+00:00                      NaN             NaN
# ...                                            ...             ...
# 2025-12-14 00:00:00+00:00             7.649634e+08        0.765736
# 2025-12-15 00:00:00+00:00             7.582439e+08        0.759010
# 2025-12-16 00:00:00+00:00             7.547481e+08        0.755510
# 2025-12-17 00:00:00+00:00             7.580528e+08        0.758818
# 2025-12-18 00:00:00+00:00             7.486195e+08        0.749376
#
#                                  supply
# 2024-04-01 00:00:00+00:00           NaN
# 2024-04-02 00:00:00+00:00           NaN
# 2024-04-03 00:00:00+00:00           NaN
# 2024-04-04 00:00:00+00:00           NaN
# 2024-04-05 00:00:00+00:00           NaN
# ...                                 ...
# 2025-12-14 00:00:00+00:00  9.989910e+08
# 2025-12-15 00:00:00+00:00  9.989910e+08
# 2025-12-16 00:00:00+00:00  9.989910e+08
# 2025-12-17 00:00:00+00:00  9.989910e+08
# 2025-12-18 00:00:00+00:00  9.989910e+08
#
# [627 rows x 58 columns]

# %%
res_df.to_csv("data/dataset1.csv", index_label="timestamp")

# %%
res_df.corr()
# Out:
#                          Open_NDX  High_NDX   Low_NDX  Close_NDX  Volume_NDX  \
# Open_NDX                 1.000000  0.997850  0.997707   0.995466    0.151853
# High_NDX                 0.997850  1.000000  0.996475   0.997765    0.178444
# Low_NDX                  0.997707  0.996475  1.000000   0.997883    0.114432
# Close_NDX                0.995466  0.997765  0.997883   1.000000    0.138954
# Volume_NDX               0.151853  0.178444  0.114432   0.138954    1.000000
# Dividends_NDX           -0.009587 -0.004847 -0.005936  -0.002864    0.161304
# Stock Splits_NDX              NaN       NaN       NaN        NaN         NaN
# Capital Gains_QQQ             NaN       NaN       NaN        NaN         NaN
# Open_^VIX                0.986435  0.987789  0.990056   0.990965    0.139572
# High_^VIX                0.986435  0.987789  0.990056   0.990965    0.139572
# Low_^VIX                 0.986435  0.987789  0.990056   0.990965    0.139572
# Close_^VIX               0.986435  0.987789  0.990056   0.990965    0.139572
# Volume_^VIX                   NaN       NaN       NaN        NaN         NaN
# Dividends_^VIX                NaN       NaN       NaN        NaN         NaN
# Stock Splits_^VIX             NaN       NaN       NaN        NaN         NaN
# Open_QQQ                -0.136161 -0.097723 -0.154323  -0.119168    0.505765
# High_QQQ                -0.141799 -0.108576 -0.171042  -0.139678    0.622305
# Low_QQQ                 -0.107967 -0.079901 -0.130353  -0.102986    0.468523
# Close_QQQ               -0.124939 -0.101398 -0.159820  -0.139037    0.593868
# Volume_QQQ                    NaN       NaN       NaN        NaN         NaN
# Dividends_QQQ                 NaN       NaN       NaN        NaN         NaN
# Stock Splits_QQQ              NaN       NaN       NaN        NaN         NaN
# Open_BTC-USD             0.991358  0.988761  0.989877   0.987038    0.162127
# High_BTC-USD             0.989843  0.991167  0.989374   0.989635    0.184195
# Low_BTC-USD              0.988377  0.986833  0.991371   0.988841    0.127058
# Close_BTC-USD            0.986848  0.988448  0.990241   0.991372    0.146176
# Volume_BTC-USD           0.225926  0.250693  0.189887   0.213342    0.920378
# Dividends_BTC-USD       -0.002643 -0.001103  0.000509   0.001995   -0.019859
# Stock Splits_BTC-USD          NaN       NaN       NaN        NaN         NaN
# Capital Gains                 NaN       NaN       NaN        NaN         NaN
# Open_SOL-USD             0.763631  0.765525  0.761271   0.763298    0.216996
# High_SOL-USD             0.762772  0.765546  0.760689   0.763496    0.216994
# Low_SOL-USD              0.761328  0.762861  0.760616   0.762485    0.196695
# Close_SOL-USD            0.758872  0.761839  0.758275   0.761379    0.206251
# Volume_SOL-USD           0.512331  0.521009  0.505154   0.511106    0.222958
# Dividends_SOL-USD             NaN       NaN       NaN        NaN         NaN
# Stock Splits_SOL-USD          NaN       NaN       NaN        NaN         NaN
# Open                     0.380280  0.368157  0.389590   0.377626   -0.235673
# High                     0.373469  0.362763  0.383177   0.372399   -0.230841
# Low                      0.386818  0.374414  0.398803   0.386896   -0.267202
# Close                    0.372811  0.362710  0.385008   0.375077   -0.245722
# Volume                   0.444498  0.450903  0.439858   0.443184    0.219808
# Dividends                     NaN       NaN       NaN        NaN         NaN
# Stock Splits                  NaN       NaN       NaN        NaN         NaN
# DGS10                   -0.182049 -0.184386 -0.177677  -0.180136   -0.060671
# GDP                      0.865255  0.874922  0.858011   0.866979    0.371176
# FEDFUNDS                -0.820458 -0.832096 -0.809625  -0.820839   -0.329575
# WALCL                   -0.832244 -0.844084 -0.822440  -0.834048   -0.339010
# M2V                      0.888200  0.892935  0.885101   0.888918    0.286877
# M2SL                     0.885750  0.895864  0.877446   0.887014    0.391336
# DTWEXBGS                -0.286689 -0.282077 -0.294165  -0.289524   -0.192420
# market_capitalization    0.116770  0.073754  0.064517   0.128549   -0.131530
# mvrv                     0.507313  0.452886  0.429795   0.471469   -0.233516
# nupl                     0.539613  0.484801  0.458531   0.492197   -0.246579
# price                    0.116760  0.073742  0.064507   0.128541   -0.131525
# realized_capitalization -0.407920 -0.418689 -0.412421  -0.349028    0.054751
# realized_price          -0.407918 -0.418693 -0.412422  -0.349026    0.054754
# supply                   0.170597  0.252079  0.210053   0.143125   -0.055809
#
#                          Dividends_NDX  Stock Splits_NDX  Capital Gains_QQQ  \
# Open_NDX                     -0.009587               NaN                NaN
# High_NDX                     -0.004847               NaN                NaN
# Low_NDX                      -0.005936               NaN                NaN
# Close_NDX                    -0.002864               NaN                NaN
# Volume_NDX                    0.161304               NaN                NaN
# Dividends_NDX                 1.000000               NaN                NaN
# Stock Splits_NDX                   NaN               NaN                NaN
# Capital Gains_QQQ                  NaN               NaN                NaN
# Open_^VIX                    -0.002811               NaN                NaN
# High_^VIX                    -0.002811               NaN                NaN
# Low_^VIX                     -0.002811               NaN                NaN
# Close_^VIX                   -0.002811               NaN                NaN
# Volume_^VIX                        NaN               NaN                NaN
# Dividends_^VIX                     NaN               NaN                NaN
# Stock Splits_^VIX                  NaN               NaN                NaN
# Open_QQQ                      0.017266               NaN                NaN
# High_QQQ                      0.003743               NaN                NaN
# Low_QQQ                      -0.009426               NaN                NaN
# Close_QQQ                    -0.021446               NaN                NaN
# Volume_QQQ                         NaN               NaN                NaN
# Dividends_QQQ                      NaN               NaN                NaN
# Stock Splits_QQQ                   NaN               NaN                NaN
# Open_BTC-USD                 -0.006632               NaN                NaN
# High_BTC-USD                 -0.001798               NaN                NaN
# Low_BTC-USD                  -0.003468               NaN                NaN
# Close_BTC-USD                -0.000637               NaN                NaN
# Volume_BTC-USD                0.058670               NaN                NaN
# Dividends_BTC-USD            -0.016785               NaN                NaN
# Stock Splits_BTC-USD               NaN               NaN                NaN
# Capital Gains                      NaN               NaN                NaN
# Open_SOL-USD                  0.004067               NaN                NaN
# High_SOL-USD                 -0.002252               NaN                NaN
# Low_SOL-USD                   0.004578               NaN                NaN
# Close_SOL-USD                 0.000472               NaN                NaN
# Volume_SOL-USD               -0.091674               NaN                NaN
# Dividends_SOL-USD                  NaN               NaN                NaN
# Stock Splits_SOL-USD               NaN               NaN                NaN
# Open                         -0.023089               NaN                NaN
# High                         -0.032064               NaN                NaN
# Low                          -0.026933               NaN                NaN
# Close                        -0.033737               NaN                NaN
# Volume                       -0.064679               NaN                NaN
# Dividends                          NaN               NaN                NaN
# Stock Splits                       NaN               NaN                NaN
# DGS10                        -0.037024               NaN                NaN
# GDP                          -0.032701               NaN                NaN
# FEDFUNDS                      0.010094               NaN                NaN
# WALCL                        -0.002290               NaN                NaN
# M2V                          -0.036649               NaN                NaN
# M2SL                         -0.009767               NaN                NaN
# DTWEXBGS                      0.016790               NaN                NaN
# market_capitalization              NaN               NaN                NaN
# mvrv                               NaN               NaN                NaN
# nupl                               NaN               NaN                NaN
# price                              NaN               NaN                NaN
# realized_capitalization            NaN               NaN                NaN
# realized_price                     NaN               NaN                NaN
# supply                             NaN               NaN                NaN
#
#                          Open_^VIX  High_^VIX  ...       M2V      M2SL  \
# Open_NDX                  0.986435   0.986435  ...  0.888200  0.885750
# High_NDX                  0.987789   0.987789  ...  0.892935  0.895864
# Low_NDX                   0.990056   0.990056  ...  0.885101  0.877446
# Close_NDX                 0.990965   0.990965  ...  0.888918  0.887014
# Volume_NDX                0.139572   0.139572  ...  0.286877  0.391336
# Dividends_NDX            -0.002811  -0.002811  ... -0.036649 -0.009767
# Stock Splits_NDX               NaN        NaN  ...       NaN       NaN
# Capital Gains_QQQ              NaN        NaN  ...       NaN       NaN
# Open_^VIX                 1.000000   1.000000  ...  0.881396  0.872365
# High_^VIX                 1.000000   1.000000  ...  0.881396  0.872365
# Low_^VIX                  1.000000   1.000000  ...  0.881396  0.872365
# Close_^VIX                1.000000   1.000000  ...  0.881396  0.872365
# Volume_^VIX                    NaN        NaN  ...       NaN       NaN
# Dividends_^VIX                 NaN        NaN  ...       NaN       NaN
# Stock Splits_^VIX              NaN        NaN  ...       NaN       NaN
# Open_QQQ                 -0.166325  -0.166325  ...  0.030221  0.211502
# High_QQQ                 -0.181302  -0.181302  ...  0.025649  0.186064
# Low_QQQ                  -0.155463  -0.155463  ...  0.048863  0.253113
# Close_QQQ                -0.185171  -0.185171  ...  0.032280  0.211055
# Volume_QQQ                     NaN        NaN  ...       NaN       NaN
# Dividends_QQQ                  NaN        NaN  ...       NaN       NaN
# Stock Splits_QQQ               NaN        NaN  ...       NaN       NaN
# Open_BTC-USD              0.995053   0.995053  ...  0.882887  0.876197
# High_BTC-USD              0.997204   0.997204  ...  0.887042  0.884461
# Low_BTC-USD               0.998138   0.998138  ...  0.880537  0.870112
# Close_BTC-USD             0.999758   0.999758  ...  0.883621  0.877754
# Volume_BTC-USD            0.217062   0.217062  ...  0.358053  0.440513
# Dividends_BTC-USD         0.000839   0.000839  ... -0.023964 -0.010300
# Stock Splits_BTC-USD           NaN        NaN  ...       NaN       NaN
# Capital Gains                  NaN        NaN  ...       NaN       NaN
# Open_SOL-USD              0.756715   0.756715  ...  0.691184  0.818490
# High_SOL-USD              0.755927   0.755927  ...  0.689582  0.818196
# Low_SOL-USD               0.755925   0.755925  ...  0.691976  0.816975
# Close_SOL-USD             0.753885   0.753885  ...  0.688963  0.816417
# Volume_SOL-USD            0.500841   0.500841  ...  0.476923  0.463571
# Dividends_SOL-USD              NaN        NaN  ...       NaN       NaN
# Stock Splits_SOL-USD           NaN        NaN  ...       NaN       NaN
# Open                      0.362201   0.362201  ...  0.218366  0.152147
# High                      0.355805   0.355805  ...  0.211785  0.147453
# Low                       0.370426   0.370426  ...  0.231228  0.160751
# Close                     0.358070   0.358070  ...  0.219788  0.150938
# Volume                    0.432515   0.432515  ...  0.428130  0.411805
# Dividends                      NaN        NaN  ...       NaN       NaN
# Stock Splits                   NaN        NaN  ...       NaN       NaN
# DGS10                    -0.142201  -0.142201  ... -0.299590 -0.135346
# GDP                       0.851293   0.851293  ...  0.917172  0.981879
# FEDFUNDS                 -0.787506  -0.787506  ... -0.707105 -0.914987
# WALCL                    -0.801185  -0.801185  ... -0.779966 -0.956183
# M2V                       0.881396   0.881396  ...  1.000000  0.887071
# M2SL                      0.872365   0.872365  ...  0.887071  1.000000
# DTWEXBGS                 -0.325201  -0.325201  ... -0.519368 -0.391935
# market_capitalization     0.310163   0.310163  ...       NaN -0.286275
# mvrv                      0.522351   0.522351  ...       NaN  0.130159
# nupl                      0.542603   0.542603  ...       NaN  0.153584
# price                     0.310160   0.310160  ...       NaN -0.286281
# realized_capitalization  -0.073496  -0.073496  ...       NaN -0.681176
# realized_price           -0.073487  -0.073487  ...       NaN -0.681173
# supply                   -0.097008  -0.097008  ...       NaN  0.277354
#
#                          DTWEXBGS  market_capitalization      mvrv      nupl  \
# Open_NDX                -0.286689               0.116770  0.507313  0.539613
# High_NDX                -0.282077               0.073754  0.452886  0.484801
# Low_NDX                 -0.294165               0.064517  0.429795  0.458531
# Close_NDX               -0.289524               0.128549  0.471469  0.492197
# Volume_NDX              -0.192420              -0.131530 -0.233516 -0.246579
# Dividends_NDX            0.016790                    NaN       NaN       NaN
# Stock Splits_NDX              NaN                    NaN       NaN       NaN
# Capital Gains_QQQ             NaN                    NaN       NaN       NaN
# Open_^VIX               -0.325201               0.310163  0.522351  0.542603
# High_^VIX               -0.325201               0.310163  0.522351  0.542603
# Low_^VIX                -0.325201               0.310163  0.522351  0.542603
# Close_^VIX              -0.325201               0.310163  0.522351  0.542603
# Volume_^VIX                   NaN                    NaN       NaN       NaN
# Dividends_^VIX                NaN                    NaN       NaN       NaN
# Stock Splits_^VIX             NaN                    NaN       NaN       NaN
# Open_QQQ                 0.095994              -0.167393 -0.550794 -0.586688
# High_QQQ                 0.116330              -0.076247 -0.460525 -0.491392
# Low_QQQ                  0.077874              -0.026070 -0.431288 -0.467474
# Close_QQQ                0.105069              -0.043053 -0.428190 -0.450947
# Volume_QQQ                    NaN                    NaN       NaN       NaN
# Dividends_QQQ                 NaN                    NaN       NaN       NaN
# Stock Splits_QQQ              NaN                    NaN       NaN       NaN
# Open_BTC-USD            -0.325677               0.305151  0.610396  0.637292
# High_BTC-USD            -0.320406               0.279481  0.549827  0.580970
# Low_BTC-USD             -0.334314               0.224702  0.511152  0.537427
# Close_BTC-USD           -0.327815               0.292043  0.528469  0.547581
# Volume_BTC-USD          -0.251662              -0.013862 -0.244600 -0.273281
# Dividends_BTC-USD        0.017172                    NaN       NaN       NaN
# Stock Splits_BTC-USD          NaN                    NaN       NaN       NaN
# Capital Gains                 NaN                    NaN       NaN       NaN
# Open_SOL-USD            -0.146920               0.906247  0.671565  0.649669
# High_SOL-USD            -0.136741               0.926665  0.699026  0.677761
# Low_SOL-USD             -0.159035               0.921791  0.743687  0.724663
# Close_SOL-USD           -0.146466               0.902462  0.692873  0.671078
# Volume_SOL-USD          -0.015795               0.168558 -0.103586 -0.124603
# Dividends_SOL-USD             NaN                    NaN       NaN       NaN
# Stock Splits_SOL-USD          NaN                    NaN       NaN       NaN
# Open                     0.235367               0.828961  0.595284  0.564588
# High                     0.255235               0.875373  0.639665  0.610148
# Low                      0.211499               0.845104  0.656637  0.628044
# Close                    0.232421               0.799567  0.578648  0.552158
# Volume                  -0.008948               0.164033 -0.107282 -0.126403
# Dividends                     NaN                    NaN       NaN       NaN
# Stock Splits                  NaN                    NaN       NaN       NaN
# DGS10                    0.394223               0.298486  0.426899  0.435666
# GDP                     -0.402663                    NaN       NaN       NaN
# FEDFUNDS                 0.039396               0.286275 -0.130159 -0.153584
# WALCL                    0.176019               0.530953  0.119802  0.101137
# M2V                     -0.519368                    NaN       NaN       NaN
# M2SL                    -0.391935              -0.286275  0.130159  0.153584
# DTWEXBGS                 1.000000               0.059132 -0.346035 -0.380814
# market_capitalization    0.059132               1.000000  0.862132  0.842127
# mvrv                    -0.346035               0.862132  1.000000  0.995041
# nupl                    -0.380814               0.842127  0.995041  1.000000
# price                    0.059144               1.000000  0.862128  0.842122
# realized_capitalization  0.527566               0.776025  0.350914  0.322801
# realized_price           0.527572               0.776029  0.350920  0.322807
# supply                  -0.331987              -0.428480 -0.250487 -0.243252
#
#                             price  realized_capitalization  realized_price  \
# Open_NDX                 0.116760                -0.407920       -0.407918
# High_NDX                 0.073742                -0.418689       -0.418693
# Low_NDX                  0.064507                -0.412421       -0.412422
# Close_NDX                0.128541                -0.349028       -0.349026
# Volume_NDX              -0.131525                 0.054751        0.054754
# Dividends_NDX                 NaN                      NaN             NaN
# Stock Splits_NDX              NaN                      NaN             NaN
# Capital Gains_QQQ             NaN                      NaN             NaN
# Open_^VIX                0.310160                -0.073496       -0.073487
# High_^VIX                0.310160                -0.073496       -0.073487
# Low_^VIX                 0.310160                -0.073496       -0.073487
# Close_^VIX               0.310160                -0.073496       -0.073487
# Volume_^VIX                   NaN                      NaN             NaN
# Dividends_^VIX                NaN                      NaN             NaN
# Stock Splits_^VIX             NaN                      NaN             NaN
# Open_QQQ                -0.167387                 0.369834        0.369825
# High_QQQ                -0.076239                 0.431398        0.431393
# Low_QQQ                 -0.026064                 0.483506        0.483498
# Close_QQQ               -0.043050                 0.455150        0.455138
# Volume_QQQ                    NaN                      NaN             NaN
# Dividends_QQQ                 NaN                      NaN             NaN
# Stock Splits_QQQ              NaN                      NaN             NaN
# Open_BTC-USD             0.305146                -0.187668       -0.187660
# High_BTC-USD             0.279473                -0.156466       -0.156464
# Low_BTC-USD              0.224695                -0.216349       -0.216346
# Close_BTC-USD            0.292039                -0.115697       -0.115691
# Volume_BTC-USD          -0.013855                 0.283149        0.283151
# Dividends_BTC-USD             NaN                      NaN             NaN
# Stock Splits_BTC-USD          NaN                      NaN             NaN
# Capital Gains                 NaN                      NaN             NaN
# Open_SOL-USD             0.906254                 0.834669        0.834682
# High_SOL-USD             0.926673                 0.837484        0.837497
# Low_SOL-USD              0.921798                 0.770455        0.770470
# Close_SOL-USD            0.902472                 0.799464        0.799483
# Volume_SOL-USD           0.168555                 0.461117        0.461103
# Dividends_SOL-USD             NaN                      NaN             NaN
# Stock Splits_SOL-USD          NaN                      NaN             NaN
# Open                     0.828971                 0.779976        0.779993
# High                     0.875383                 0.811883        0.811900
# Low                      0.845113                 0.731658        0.731676
# Close                    0.799580                 0.747486        0.747509
# Volume                   0.164032                 0.451864        0.451852
# Dividends                     NaN                      NaN             NaN
# Stock Splits                  NaN                      NaN             NaN
# DGS10                    0.298485                 0.042173        0.042178
# GDP                           NaN                      NaN             NaN
# FEDFUNDS                 0.286281                 0.681176        0.681173
# WALCL                    0.530959                 0.824022        0.824020
# M2V                           NaN                      NaN             NaN
# M2SL                    -0.286281                -0.681176       -0.681173
# DTWEXBGS                 0.059144                 0.527566        0.527572
# market_capitalization    1.000000                 0.776025        0.776029
# mvrv                     0.862128                 0.350914        0.350920
# nupl                     0.842122                 0.322801        0.322807
# price                    1.000000                 0.776030        0.776034
# realized_capitalization  0.776030                 1.000000        1.000000
# realized_price           0.776034                 1.000000        1.000000
# supply                  -0.428513                -0.479480       -0.479536
#
#                            supply
# Open_NDX                 0.170597
# High_NDX                 0.252079
# Low_NDX                  0.210053
# Close_NDX                0.143125
# Volume_NDX              -0.055809
# Dividends_NDX                 NaN
# Stock Splits_NDX              NaN
# Capital Gains_QQQ             NaN
# Open_^VIX               -0.097008
# High_^VIX               -0.097008
# Low_^VIX                -0.097008
# Close_^VIX              -0.097008
# Volume_^VIX                   NaN
# Dividends_^VIX                NaN
# Stock Splits_^VIX             NaN
# Open_QQQ                -0.051691
# High_QQQ                -0.135897
# Low_QQQ                 -0.117102
# Close_QQQ               -0.059065
# Volume_QQQ                    NaN
# Dividends_QQQ                 NaN
# Stock Splits_QQQ              NaN
# Open_BTC-USD            -0.020973
# High_BTC-USD             0.053288
# Low_BTC-USD              0.062154
# Close_BTC-USD           -0.020284
# Volume_BTC-USD          -0.169703
# Dividends_BTC-USD             NaN
# Stock Splits_BTC-USD          NaN
# Capital Gains                 NaN
# Open_SOL-USD            -0.572173
# High_SOL-USD            -0.583476
# Low_SOL-USD             -0.577388
# Close_SOL-USD           -0.638246
# Volume_SOL-USD          -0.020942
# Dividends_SOL-USD             NaN
# Stock Splits_SOL-USD          NaN
# Open                    -0.603031
# High                    -0.625556
# Low                     -0.600220
# Close                   -0.679977
# Volume                  -0.056818
# Dividends                     NaN
# Stock Splits                  NaN
# DGS10                   -0.094588
# GDP                           NaN
# FEDFUNDS                -0.277354
# WALCL                   -0.361090
# M2V                           NaN
# M2SL                     0.277354
# DTWEXBGS                -0.331987
# market_capitalization   -0.428480
# mvrv                    -0.250487
# nupl                    -0.243252
# price                   -0.428513
# realized_capitalization -0.479480
# realized_price          -0.479536
# supply                   1.000000
#
# [58 rows x 58 columns]
